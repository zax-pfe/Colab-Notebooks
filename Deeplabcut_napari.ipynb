# %%
# !pip install deeplabcut

# %%
# Clone the entire deeplabcut repo so we can use the demo data:
# !git clone -l -s https://github.com/DeepLabCut/DeepLabCut.git cloned-DLC-repo
# %cd cloned-DLC-repo
# !ls

# %%
# %cd /content/cloned-DLC-repo/examples/openfield-Pranav-2018-10-30
# !ls

# %%
import deeplabcut
print(f'deepLabCut version: {deeplabcut. __version__}')

# %%
video_path = "/content/cloned-DLC-repo/examples/Reaching-Mackenzie-2018-08-30/videos/reachingvideo1.avi"

# %%
task='Reaching' # Enter the name of your experiment Task
experimenter='Mackenzie' # Enter the name of the experimenter
video=[video_path] # Enter the paths of your videos OR FOLDER you want to grab frames from.

path_config_file=deeplabcut.create_new_project(task,experimenter,video,copy_videos=True) 

# NOTE: The function returns the path, where your project is. 
# You could also enter this manually (e.g. if the project is already created and you want to pick up, where you stopped...)
#path_config_file = '/home/Mackenzie/Reaching/config.yaml' # Enter the path of the config file that was just created from the above step (check the folder)
# Out:
# Created "/content/cloned-DLC-repo/examples/openfield-Pranav-2018-10-30/Reaching-Mackenzie-2022-10-19/videos"
# Created "/content/cloned-DLC-repo/examples/openfield-Pranav-2018-10-30/Reaching-Mackenzie-2022-10-19/labeled-data"
# Created "/content/cloned-DLC-repo/examples/openfield-Pranav-2018-10-30/Reaching-Mackenzie-2022-10-19/training-datasets"
# Created "/content/cloned-DLC-repo/examples/openfield-Pranav-2018-10-30/Reaching-Mackenzie-2022-10-19/dlc-models"
# Copying the videos
# /content/cloned-DLC-repo/examples/openfield-Pranav-2018-10-30/Reaching-Mackenzie-2022-10-19/videos/reachingvideo1.avi
# Generated "/content/cloned-DLC-repo/examples/openfield-Pranav-2018-10-30/Reaching-Mackenzie-2022-10-19/config.yaml"
#
# A new project with name Reaching-Mackenzie-2022-10-19 is created at /content/cloned-DLC-repo/examples/openfield-Pranav-2018-10-30 and a configurable file (config.yaml) is stored there. Change the parameters in this file to adapt to your project's needs.
#  Once you have changed the configuration file, use the function 'extract_frames' to select frames for labeling.
# . [OPTIONAL] Use the function 'add_new_videos' to add new videos to your project (at any stage).

# %%
# %cd /content/cloned-DLC-repo/examples/Reaching-Mackenzie-2018-08-30/videos
# !ls

# %%
deeplabcut.extract_frames?

# %%
#there are other ways to grab frames, such as uniformly; please see the paper:

#AUTOMATIC:
deeplabcut.extract_frames(path_config_file)
# Out:
# Config file read successfully.
# Do you want to extract (perhaps additional) frames for video: /content/cloned-DLC-repo/examples/openfield-Pranav-2018-10-30/Reaching-Mackenzie-2022-10-19/videos/reachingvideo1.avi ?
# yes/noyes
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 0.0  seconds to 8.53  seconds.
# Extracting and downsampling... 256  frames from the video.
# 256it [00:06, 39.40it/s]
# Kmeans clustering ... (this might take a while)
# Frames were successfully extracted, for the videos listed in the config.yaml file.
#
# You can now label the frames using the function 'label_frames' (Note, you should label frames extracted from diverse videos (and many videos; we do not recommend training on single videos!)).

# %%
# deeplabcut.label_frames()

# %%
# !pip install napari-deeplabcut
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement napari-deeplabcut (from versions: none)
# ERROR: No matching distribution found for napari-deeplabcut

# %%
# %gui qt5
import napari
napari.Viewer()
# Out:
#   File "<ipython-input-15-08aff3904dc5>", line 2
#     import napari-deeplabcut
#                  ^
# SyntaxError: invalid syntax
