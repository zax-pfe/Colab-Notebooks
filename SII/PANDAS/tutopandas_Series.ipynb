# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']

my_list = [10,20,30]

arr = np.array([10,20,30])

d = {'a':10, 'b':20, 'c':30}

# %%
pd.Series(data=my_list, index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_list, labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr, labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
sales_Q1 = pd.Series(data=[250,450,200,150], index=['USA','Chine','India','Brazil'])

# %%
sales_Q1
# Out:
# USA       250
# Chine     450
# India     200
# Brazil    150
# dtype: int64

# %%
sales_Q2 = pd.Series(data=[260,500,210,100], index=['USA','Chine','India','Japan'])

# %%
sales_Q2
# Out:
# USA      260
# Chine    500
# India    210
# Japan    100
# dtype: int64

# %%
sales_Q2['USA']
# Out:
# 260

# %%
sales_Q2[0]
# Out:
# 260

# %%
sales_Q1+sales_Q2
# Out:
# Brazil      NaN
# Chine     950.0
# India     410.0
# Japan       NaN
# USA       510.0
# dtype: float64
