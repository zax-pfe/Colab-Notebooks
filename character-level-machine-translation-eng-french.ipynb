# %%
import numpy as np 
import pandas as pd

# %%
from keras.models import Model
from keras.layers import Input, LSTM, Dense
import numpy as np

# %%
import codecs
batch_size = 64  
epochs = 50 
latent_dim = 256  
num_samples = 10000  
data_path = 'eng_-french.csv'

# %%
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()

# %%
data=pd.read_csv(data_path)
data.head()
print(data.columns)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-4acfc88785ea> in <module>()
# ----> 1 data=pd.read_csv(data_path)
#       2 data.head()
#       3 print(data.columns)
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'eng_-french.csv'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4918730032125215450
# ]

# %%
input_texts=data['English words/sentences']
target_texts=data['French words/sentences']
input_texts=input_texts[:75000]
target_texts=target_texts[:75000]
target_texts=['\t'+text+'\n' for text in target_texts]

# %%
print(input_texts.shape)
# Out:
# (75000,)

# %%
for text in input_texts:
    for char in text:
        input_characters.add(char)
input_characters
for text in target_texts:
    for char in text:
        target_characters.add(char)

# %%
input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

# %%
print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of samples: 75000
# Number of unique input tokens: 79
# Number of unique output tokens: 105
# Max sequence length for inputs: 27
# Max sequence length for outputs: 74

# %%
input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

# %%
input_token_index

# %%
encoder_input_data = np.zeros((len(input_texts), max_encoder_seq_length, num_encoder_tokens),dtype='float32')
decoder_input_data = np.zeros((len(input_texts), max_decoder_seq_length, num_decoder_tokens),dtype='float32')
decoder_target_data = np.zeros((len(input_texts), max_decoder_seq_length, num_decoder_tokens),dtype='float32')

# %%
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    encoder_input_data[i, t + 1:, input_token_index[' ']] = 1.
    
    for t, char in enumerate(target_text):
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.            
    decoder_input_data[i, t + 1:, target_token_index[' ']] = 1.    
    decoder_target_data[i, t:, target_token_index[' ']] = 1.

# %%
print(encoder_input_data.shape)
print(decoder_input_data.shape)
print(decoder_target_data.shape)

# %%
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
encoder_states = [state_h, state_c]

decoder_inputs = Input(shape=(None, num_decoder_tokens))
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)


model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy',metrics=['accuracy'])

model.fit([encoder_input_data, decoder_input_data],
          decoder_target_data,batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)
# Out:
# Epoch 1/50
# 938/938 [==============================] - 19s 20ms/step - loss: 0.7825 - accuracy: 0.7831 - val_loss: 0.7593 - val_accuracy: 0.7727
# Epoch 2/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.5084 - accuracy: 0.8482 - val_loss: 0.6012 - val_accuracy: 0.8190
# Epoch 3/50
# 938/938 [==============================] - 16s 18ms/step - loss: 0.4199 - accuracy: 0.8738 - val_loss: 0.5255 - val_accuracy: 0.8416
# Epoch 4/50
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3720 - accuracy: 0.8878 - val_loss: 0.4856 - val_accuracy: 0.8538
# Epoch 5/50
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3416 - accuracy: 0.8963 - val_loss: 0.4581 - val_accuracy: 0.8611
# Epoch 6/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.3202 - accuracy: 0.9023 - val_loss: 0.4366 - val_accuracy: 0.8675
# Epoch 7/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.3040 - accuracy: 0.9071 - val_loss: 0.4246 - val_accuracy: 0.8716
# Epoch 8/50
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2909 - accuracy: 0.9108 - val_loss: 0.4150 - val_accuracy: 0.8739
# Epoch 9/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2803 - accuracy: 0.9139 - val_loss: 0.4077 - val_accuracy: 0.8764
# Epoch 10/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2712 - accuracy: 0.9166 - val_loss: 0.4019 - val_accuracy: 0.8782
# Epoch 11/50
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2635 - accuracy: 0.9187 - val_loss: 0.3971 - val_accuracy: 0.8795
# Epoch 12/50
# 938/938 [==============================] - 16s 18ms/step - loss: 0.2564 - accuracy: 0.9209 - val_loss: 0.3944 - val_accuracy: 0.8810
# Epoch 13/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2499 - accuracy: 0.9228 - val_loss: 0.3904 - val_accuracy: 0.8822
# Epoch 14/50
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2439 - accuracy: 0.9245 - val_loss: 0.3907 - val_accuracy: 0.8819
# Epoch 15/50
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2386 - accuracy: 0.9262 - val_loss: 0.3908 - val_accuracy: 0.8828
# Epoch 16/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2338 - accuracy: 0.9275 - val_loss: 0.3866 - val_accuracy: 0.8841
# Epoch 17/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2292 - accuracy: 0.9288 - val_loss: 0.3860 - val_accuracy: 0.8847
# Epoch 18/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2249 - accuracy: 0.9301 - val_loss: 0.3884 - val_accuracy: 0.8847
# Epoch 19/50
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2209 - accuracy: 0.9314 - val_loss: 0.3879 - val_accuracy: 0.8847
# Epoch 20/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2170 - accuracy: 0.9324 - val_loss: 0.3865 - val_accuracy: 0.8852
# Epoch 21/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2135 - accuracy: 0.9334 - val_loss: 0.3886 - val_accuracy: 0.8853
# Epoch 22/50
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2102 - accuracy: 0.9345 - val_loss: 0.3895 - val_accuracy: 0.8854
# Epoch 23/50
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2070 - accuracy: 0.9354 - val_loss: 0.3896 - val_accuracy: 0.8859
# Epoch 24/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2038 - accuracy: 0.9363 - val_loss: 0.3928 - val_accuracy: 0.8853
# Epoch 25/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2010 - accuracy: 0.9372 - val_loss: 0.3941 - val_accuracy: 0.8849
# Epoch 26/50
# 938/938 [==============================] - 17s 18ms/step - loss: 0.1982 - accuracy: 0.9380 - val_loss: 0.3937 - val_accuracy: 0.8858
# Epoch 27/50
# 938/938 [==============================] - 16s 18ms/step - loss: 0.1955 - accuracy: 0.9388 - val_loss: 0.3960 - val_accuracy: 0.8853
# Epoch 28/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1930 - accuracy: 0.9394 - val_loss: 0.3995 - val_accuracy: 0.8855
# Epoch 29/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1904 - accuracy: 0.9403 - val_loss: 0.3998 - val_accuracy: 0.8857
# Epoch 30/50
# 938/938 [==============================] - 17s 18ms/step - loss: 0.1883 - accuracy: 0.9409 - val_loss: 0.4017 - val_accuracy: 0.8854
# Epoch 31/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1861 - accuracy: 0.9415 - val_loss: 0.4033 - val_accuracy: 0.8852
# Epoch 32/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1838 - accuracy: 0.9422 - val_loss: 0.4058 - val_accuracy: 0.8854
# Epoch 33/50
# 938/938 [==============================] - 17s 18ms/step - loss: 0.1817 - accuracy: 0.9428 - val_loss: 0.4087 - val_accuracy: 0.8847
# Epoch 34/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1798 - accuracy: 0.9432 - val_loss: 0.4122 - val_accuracy: 0.8841
# Epoch 35/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1780 - accuracy: 0.9440 - val_loss: 0.4137 - val_accuracy: 0.8842
# Epoch 36/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1761 - accuracy: 0.9445 - val_loss: 0.4158 - val_accuracy: 0.8846
# Epoch 37/50
# 938/938 [==============================] - 17s 18ms/step - loss: 0.1743 - accuracy: 0.9449 - val_loss: 0.4148 - val_accuracy: 0.8846
# Epoch 38/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1726 - accuracy: 0.9454 - val_loss: 0.4204 - val_accuracy: 0.8840
# Epoch 39/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1709 - accuracy: 0.9460 - val_loss: 0.4245 - val_accuracy: 0.8832
# Epoch 40/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1693 - accuracy: 0.9465 - val_loss: 0.4262 - val_accuracy: 0.8829
# Epoch 41/50
# 938/938 [==============================] - 17s 18ms/step - loss: 0.1678 - accuracy: 0.9467 - val_loss: 0.4284 - val_accuracy: 0.8834
# Epoch 42/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1663 - accuracy: 0.9473 - val_loss: 0.4296 - val_accuracy: 0.8833
# Epoch 43/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1648 - accuracy: 0.9477 - val_loss: 0.4308 - val_accuracy: 0.8832
# Epoch 44/50
# 938/938 [==============================] - 17s 18ms/step - loss: 0.1633 - accuracy: 0.9481 - val_loss: 0.4315 - val_accuracy: 0.8831
# Epoch 45/50
# 938/938 [==============================] - 17s 18ms/step - loss: 0.1620 - accuracy: 0.9486 - val_loss: 0.4342 - val_accuracy: 0.8834
# Epoch 46/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1607 - accuracy: 0.9490 - val_loss: 0.4417 - val_accuracy: 0.8818
# Epoch 47/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1594 - accuracy: 0.9493 - val_loss: 0.4389 - val_accuracy: 0.8828
# Epoch 48/50
# 938/938 [==============================] - 17s 18ms/step - loss: 0.1579 - accuracy: 0.9498 - val_loss: 0.4438 - val_accuracy: 0.8814
# Epoch 49/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1569 - accuracy: 0.9500 - val_loss: 0.4457 - val_accuracy: 0.8820
# Epoch 50/50
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1556 - accuracy: 0.9504 - val_loss: 0.4460 - val_accuracy: 0.8822

# %%
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model([decoder_inputs] + decoder_states_inputs,[decoder_outputs] + decoder_states)

# %%
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index['\t']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
for seq_index in range(100):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts[seq_index])
    print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: Hi.
# Decoded sentence: Salut.
#
# -
# Input sentence: Run!
# Decoded sentence: Cours ça !
#
# -
# Input sentence: Run!
# Decoded sentence: Cours ça !
#
# -
# Input sentence: Who?
# Decoded sentence: Qui ?
#
# -
# Input sentence: Wow!
# Decoded sentence: Ma compassiffe.
#
# -
# Input sentence: Fire!
# Decoded sentence: La femme a cassée.
#
# -
# Input sentence: Help!
# Decoded sentence: À l'entende !
#
# -
# Input sentence: Jump.
# Decoded sentence: Allez en voulute !
#
# -
# Input sentence: Stop!
# Decoded sentence: Asseyez-le !
#
# -
# Input sentence: Stop!
# Decoded sentence: Asseyez-le !
#
# -
# Input sentence: Stop!
# Decoded sentence: Asseyez-le !
#
# -
# Input sentence: Wait!
# Decoded sentence: Attendez !
#
# -
# Input sentence: Wait!
# Decoded sentence: Attendez !
#
# -
# Input sentence: Go on.
# Decoded sentence: Va voir.
#
# -
# Input sentence: Go on.
# Decoded sentence: Va voir.
#
# -
# Input sentence: Go on.
# Decoded sentence: Va voir.
#
# -
# Input sentence: Hello!
# Decoded sentence: Salut cette fille !
#
# -
# Input sentence: Hello!
# Decoded sentence: Salut cette fille !
#
# -
# Input sentence: I see.
# Decoded sentence: Je vois le chemin.
#
# -
# Input sentence: I try.
# Decoded sentence: Je parles la pièce.
#
# -
# Input sentence: I won!
# Decoded sentence: Je me fais de tout !
#
# -
# Input sentence: I won!
# Decoded sentence: Je me fais de tout !
#
# -
# Input sentence: I won.
# Decoded sentence: Je le ferai.
#
# -
# Input sentence: Oh no!
# Decoded sentence: Oh nom a cafous.
#
# -
# Input sentence: Attack!
# Decoded sentence: Attant !
#
# -
# Input sentence: Attack!
# Decoded sentence: Attant !
#
# -
# Input sentence: Cheers!
# Decoded sentence: Laisse tomber !
#
# -
# Input sentence: Cheers!
# Decoded sentence: Laisse tomber !
#
# -
# Input sentence: Cheers!
# Decoded sentence: Laisse tomber !
#
# -
# Input sentence: Cheers!
# Decoded sentence: Laisse tomber !
#
# -
# Input sentence: Get up.
# Decoded sentence: Enlève !
#
# -
# Input sentence: Go now.
# Decoded sentence: Va à l'école.
#
# -
# Input sentence: Go now.
# Decoded sentence: Va à l'école.
#
# -
# Input sentence: Go now.
# Decoded sentence: Va à l'école.
#
# -
# Input sentence: Got it!
# Decoded sentence: Lâche-moi.
#
# -
# Input sentence: Got it!
# Decoded sentence: Lâche-moi.
#
# -
# Input sentence: Got it?
# Decoded sentence: Lâche-toi.
#
# -
# Input sentence: Got it?
# Decoded sentence: Lâche-toi.
#
# -
# Input sentence: Got it?
# Decoded sentence: Lâche-toi.
#
# -
# Input sentence: Hop in.
# Decoded sentence: Montenas.
#
# -
# Input sentence: Hop in.
# Decoded sentence: Montenas.
#
# -
# Input sentence: Hug me.
# Decoded sentence: Partez-vous la vaisselle.
#
# -
# Input sentence: Hug me.
# Decoded sentence: Partez-vous la vaisselle.
#
# -
# Input sentence: I fell.
# Decoded sentence: Je suis tombé.
#
# -
# Input sentence: I fell.
# Decoded sentence: Je suis tombé.
#
# -
# Input sentence: I know.
# Decoded sentence: Je sais.
#
# -
# Input sentence: I left.
# Decoded sentence: Je suis parti.
#
# -
# Input sentence: I left.
# Decoded sentence: Je suis parti.
#
# -
# Input sentence: I lied.
# Decoded sentence: J'ai menti.
#
# -
# Input sentence: I lost.
# Decoded sentence: J'ai perdu.
#
# -
# Input sentence: I paid.
# Decoded sentence: J'ai payé.
#
# -
# Input sentence: I'm 19.
# Decoded sentence: Je suis gros.
#
# -
# Input sentence: I'm OK.
# Decoded sentence: Je suis distraite.
#
# -
# Input sentence: I'm OK.
# Decoded sentence: Je suis distraite.
#
# -
# Input sentence: Listen.
# Decoded sentence: Écoute !
#
# -
# Input sentence: No way!
# Decoded sentence: Il n'a pas l'air !
#
# -
# Input sentence: No way!
# Decoded sentence: Il n'a pas l'air !
#
# -
# Input sentence: No way!
# Decoded sentence: Il n'a pas l'air !
#
# -
# Input sentence: No way!
# Decoded sentence: Il n'a pas l'air !
#
# -
# Input sentence: No way!
# Decoded sentence: Il n'a pas l'air !
#
# -
# Input sentence: No way!
# Decoded sentence: Il n'a pas l'air !
#
# -
# Input sentence: No way!
# Decoded sentence: Il n'a pas l'air !
#
# -
# Input sentence: No way!
# Decoded sentence: Il n'a pas l'air !
#
# -
# Input sentence: No way!
# Decoded sentence: Il n'a pas l'air !
#
# -
# Input sentence: Really?
# Decoded sentence: Est-ce que ça va ?
#
# -
# Input sentence: Really?
# Decoded sentence: Est-ce que ça va ?
#
# -
# Input sentence: Really?
# Decoded sentence: Est-ce que ça va ?
#
# -
# Input sentence: Thanks.
# Decoded sentence: Merci.
#
# -
# Input sentence: We try.
# Decoded sentence: Nous sommes confiantes.
#
# -
# Input sentence: We won.
# Decoded sentence: Nous avons raté.
#
# -
# Input sentence: We won.
# Decoded sentence: Nous avons raté.
#
# -
# Input sentence: We won.
# Decoded sentence: Nous avons raté.
#
# -
# Input sentence: We won.
# Decoded sentence: Nous avons raté.
#
# -
# Input sentence: Ask Tom.
# Decoded sentence: Demande à Tom.
#
# -
# Input sentence: Awesome!
# Decoded sentence: Quelqu'un a-t-il été blessé ?
#
# -
# Input sentence: Be calm.
# Decoded sentence: Soyez calme !
#
# -
# Input sentence: Be calm.
# Decoded sentence: Soyez calme !
#
# -
# Input sentence: Be calm.
# Decoded sentence: Soyez calme !
#
# -
# Input sentence: Be cool.
# Decoded sentence: Soyez confiant !
#
# -
# Input sentence: Be fair.
# Decoded sentence: Sois ici !
#
# -
# Input sentence: Be fair.
# Decoded sentence: Sois ici !
#
# -
# Input sentence: Be fair.
# Decoded sentence: Sois ici !
#
# -
# Input sentence: Be fair.
# Decoded sentence: Sois ici !
#
# -
# Input sentence: Be fair.
# Decoded sentence: Sois ici !
#
# -
# Input sentence: Be fair.
# Decoded sentence: Sois ici !
#
# -
# Input sentence: Be kind.
# Decoded sentence: Sois un cours !
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez gentilles !
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez gentilles !
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez gentilles !
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez gentilles !
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez gentilles !
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez gentilles !
#
# -
# Input sentence: Beat it.
# Decoded sentence: Abrime les pommes !
#
# -
# Input sentence: Call me.
# Decoded sentence: Appellez-moi !
#
# -
# Input sentence: Call me.
# Decoded sentence: Appellez-moi !
#
# -
# Input sentence: Call us.
# Decoded sentence: Appelle-nous !
#
# -
# Input sentence: Call us.
# Decoded sentence: Appelle-nous !
#
# -
# Input sentence: Come in.
# Decoded sentence: Entre.
#
# -
# Input sentence: Come in.
# Decoded sentence: Entre.
#
# -
# Input sentence: Come in.
# Decoded sentence: Entre.

# %%
model.save('model.h5')
encoder_model.save('encoder_model.h5')
decoder_model.save('decoder_model.h5')
